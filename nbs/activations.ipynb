# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
imgs = np.load('activations.npy')
imgs.shape
# Out:
# (5, 16, 16)

# %%
fig, axs = plt.subplots(nrows=1, ncols=5, figsize=(12, 12))

for i in range(5):
    axs[i].imshow(imgs[i])
    axs[i].axis('off')
